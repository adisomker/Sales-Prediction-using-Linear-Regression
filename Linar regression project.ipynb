# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("Advertising.csv",index_col=0)

# %%
data.head()
# Out:
#       TV  radio  newspaper  sales
# 1  230.1   37.8       69.2   22.1
# 2   44.5   39.3       45.1   10.4
# 3   17.2   45.9       69.3    9.3
# 4  151.5   41.3       58.5   18.5
# 5  180.8   10.8       58.4   12.9

# %% [markdown]
# # Data Preprocesing

# %%
x = data["TV"]
y = data["sales"]

# %%
plt.scatter(x,y)
plt.xlabel("TV")
plt.ylabel("sales")
plt.title("Sales vs TV Advertising")
# Out:
# Text(0.5, 1.0, 'Sales vs TV Advertising')

# %%
x = data["radio"]
y = data["sales"]

# %%
plt.scatter(x,y)
plt.xlabel("radio")
plt.ylabel("sales")
plt.title("Sales vs radio Advertising")
# Out:
# Text(0.5, 1.0, 'Sales vs radio Advertising')

# %%
x = data["newspaper"]
y = data["sales"]

# %%
plt.scatter(x,y)
plt.xlabel("newspaper")
plt.ylabel("sales")
plt.title("Sales vs newspaper Advertising")
# Out:
# Text(0.5, 1.0, 'Sales vs newspaper Advertising')

# %%
sns.heatmap(data.corr(),annot=True)
# Out:
# <Axes: >

# %%
data.isnull().sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 data.isnull().sum()
#
# NameError: name 'data' is not defined

# %%
data = pd.read_csv("Advertising.csv",index_col=0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 data = pd.read_csv("Advertising.csv",index_col=0)
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd

# %%
data = pd.read_csv("Advertising.csv",index_col=0)

# %%
data.isnull().sum()
# Out:
# TV           0
# radio        0
# newspaper    0
# sales        0
# dtype: int64

# %%
plt.boxplot(data["TV"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 plt.boxplot(data["TV"])
#
# NameError: name 'plt' is not defined

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.boxplot(data["TV"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x166534bd510>,
#   <matplotlib.lines.Line2D at 0x166534bdc90>],
#  'caps': [<matplotlib.lines.Line2D at 0x166534beed0>,
#   <matplotlib.lines.Line2D at 0x166534bfc10>],
#  'boxes': [<matplotlib.lines.Line2D at 0x166534bc590>],
#  'medians': [<matplotlib.lines.Line2D at 0x166534cc810>],
#  'fliers': [<matplotlib.lines.Line2D at 0x166534cd2d0>],
#  'means': []}

# %%
plt.boxplot(data["newspaper"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x16657f47790>,
#   <matplotlib.lines.Line2D at 0x16657f66150>],
#  'caps': [<matplotlib.lines.Line2D at 0x16657f66a50>,
#   <matplotlib.lines.Line2D at 0x16657f67290>],
#  'boxes': [<matplotlib.lines.Line2D at 0x16657f35a10>],
#  'medians': [<matplotlib.lines.Line2D at 0x16657f67ad0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x16657f78250>],
#  'means': []}

# %%
plt.boxplot(data["radio"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x166580c31d0>,
#   <matplotlib.lines.Line2D at 0x166580c3bd0>],
#  'caps': [<matplotlib.lines.Line2D at 0x166580d8610>,
#   <matplotlib.lines.Line2D at 0x166580d8e10>],
#  'boxes': [<matplotlib.lines.Line2D at 0x166580c2990>],
#  'medians': [<matplotlib.lines.Line2D at 0x166580d9750>],
#  'fliers': [<matplotlib.lines.Line2D at 0x16657df9f50>],
#  'means': []}

# %%
sns.scatterplot(data)
# Out:
# <Axes: >

# %% [markdown]
# # Formula for liner regression

# %%
#y = beta 0 + beta 1 X 1

# %%
#y=b0+b1x1

# %%
x = data[["TV","radio","newspaper"]]
y = data[["sales"]]

# %%
x
# Out:
#         TV  radio  newspaper
# 1    230.1   37.8       69.2
# 2     44.5   39.3       45.1
# 3     17.2   45.9       69.3
# 4    151.5   41.3       58.5
# 5    180.8   10.8       58.4
# ..     ...    ...        ...
# 196   38.2    3.7       13.8
# 197   94.2    4.9        8.1
# 198  177.0    9.3        6.4
# 199  283.6   42.0       66.2
# 200  232.1    8.6        8.7
#
# [200 rows x 3 columns]

# %%
y
# Out:
#      sales
# 1     22.1
# 2     10.4
# 3      9.3
# 4     18.5
# 5     12.9
# ..     ...
# 196    7.6
# 197    9.7
# 198   12.8
# 199   25.5
# 200   13.4
#
# [200 rows x 1 columns]

# %%
import sklearn

# %%
from sklearn.model_selection import train_test_split

# %%
print("shape of x",x.shape)
print("shape of y",y.shape)
# Out:
# shape of x (200, 3)
# shape of y (200, 1)

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.20)

# %%
print("the shape of x-train",x_train.shape)
print("the shape of x-test",x_test.shape)
print("the shape of y-train",y_train.shape)
print("the shape of y-test",y_test.shape)
# Out:
# the shape of x-train (160, 3)
# the shape of x-test (40, 3)
# the shape of y-train (160, 1)
# the shape of y-test (40, 1)

# %%
from sklearn.linear_model import LinearRegression

# %%
lm = LinearRegression()

# %%
model = lm.fit(x_train,y_train)

# %%
print(lm.coef_)
# Out:
# [[ 0.04504155  0.18535844 -0.00239511]]

# %%
print(lm.intercept_)
# Out:
# [3.16914803]

# %%
# y = b0 + b1x1

# %%
bzero = 3.16914803

# %%
bone = 0.04504155

# %%
btwo = 0.18535844

# %%
bthree = -0.00239511

# %%
y = bzero + bone*228 + btwo*37.7 + bthree*32

# %%
y
# Out:
# 20.349991098

# %%
y_pred = lm.predict(x_test)

# %%
print(y_pred)
# Out:
# [[18.30017385]
#  [22.16670037]
#  [11.38712446]
#  [ 8.26692234]
#  [23.56942935]
#  [10.44686449]
#  [21.50399262]
#  [12.1883843 ]
#  [12.85000685]
#  [15.48090443]
#  [ 8.93207578]
#  [ 4.6281468 ]
#  [16.87827682]
#  [17.50813229]
#  [18.15319972]
#  [ 8.58421693]
#  [17.10759839]
#  [21.14091238]
#  [17.92393093]
#  [12.82293014]
#  [23.29746142]
#  [13.40113894]
#  [11.52891638]
#  [10.68941075]
#  [11.50598176]
#  [15.15104208]
#  [13.98202434]
#  [18.8386335 ]
#  [14.7241451 ]
#  [12.42884444]
#  [ 7.91749379]
#  [16.49625765]
#  [10.60972294]
#  [ 9.22196729]
#  [13.93171977]
#  [19.64572839]
#  [ 7.99869276]
#  [13.84535961]
#  [12.03953226]
#  [17.83969774]]

# %%
new_df = pd.DataFrame()
new_df = x_test
new_df['actual sales']= y_test
new_df['predicted sales']= y_pred
new_df
# Out:
#         TV  radio  newspaper  actual sales  predicted sales
# 151  280.7   13.9       37.0          16.1        18.300174
# 129  220.3   49.0        3.2          24.7        22.166700
# 32   112.9   17.4       38.6          11.9        11.387124
# 25    62.3   12.6       18.3           9.7         8.266922
# 199  283.6   42.0       66.2          25.5        23.569429
# 73    26.8   33.0       19.3           8.8        10.446864
# 31   292.9   28.3       43.2          21.4        21.503993
# 8    120.2   19.6       11.6          13.2        12.188384
# 198  177.0    9.3        6.4          12.8        12.850007
# 119  125.7   36.9       79.2          15.9        15.480904
# 79     5.4   29.9        9.4           5.3         8.932076
# 193   17.2    4.1       31.6           5.9         4.628147
# 100  135.2   41.7       45.9          17.2        16.878277
# 4    151.5   41.3       58.5          18.5        17.508132
# 154  171.3   39.7       37.7          19.0        18.153200
# 133    8.4   27.2        2.1           5.7         8.584217
# 169  215.4   23.6       57.6          17.1        17.107598
# 56   198.9   49.4       60.0          23.7        21.140912
# 170  284.3   10.6        6.4          15.0        17.923931
# 58   136.2   19.2       16.6          13.2        12.822930
# 37   266.9   43.8        5.0          25.4        23.297461
# 168  206.8    5.2       19.4          12.2        13.401139
# 137   25.6   39.0        9.3           9.5        11.528916
# 72   109.8   14.3       31.7          12.4        10.689411
# 81    76.4   26.7       22.3          11.8        11.505982
# 46   175.1   22.5       31.5          14.9        15.151042
# 44   206.9    8.4       26.4          12.9        13.982024
# 34   265.6   20.0        0.3          17.4        18.838634
# 111  225.8    8.2       56.5          13.4        14.724145
# 160  131.7   18.4       34.6          12.9        12.428844
# 122   18.8   21.7       50.4           7.0         7.917494
# 195  149.7   35.6        6.0          17.3        16.496258
# 127    7.8   38.9       50.6           6.6        10.609723
# 126   87.2   11.8       25.9          10.6         9.221967
# 113  175.7   15.4        2.4          14.1        13.931720
# 110  255.4   26.9        5.5          19.8        19.645728
# 66    69.0    9.3        0.9           9.3         7.998693
# 78   120.5   28.5       14.2          14.2        13.845360
# 174  168.4    7.1       12.8          11.7        12.039532
# 106  137.9   46.4       59.0          19.2        17.839698

# %%
from sklearn.metrics import r2_score,mean_squared_error
import numpy as np

r2=r2_score(y_test,y_pred)
print("R-squared:", r2*100)

rmse=np.sqrt(mean_squared_error(y_test,y_pred))
print("RMSE:",rmse)
# Out:
# R-squared: 90.79386351127506
# RMSE: 1.6044691185805486

# %%
new_df.to_csv("update.csv")
